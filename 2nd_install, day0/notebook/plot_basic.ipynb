# %% [markdown]
# # Jupyter notebook 에서 plot 사용하기
# - 참고자료
#     - [Jupyter notebook 이해하기 p.136](https://www.slideshare.net/dahlmoon/jupyter-notebok-20160815/136)

# %% [markdown]
# ## [matplotlib](http://matplotlib.org/index.html)
# - python에서 그래프나 그림을 화면에 출력을 해줄수 있게 해주는 라이브러리
# - 출력 종류
#     - [matplotlib gallery 참고](http://matplotlib.org/gallery.html)

# %% [markdown]
# ## [Seaborn](https://seaborn.pydata.org/index.html)
# - matplotlib 기반의 visualization 라이브러리
# - 통계데이터 출력에 특화되어 있음
# - 출력 종류
#     - [Seaborn gallery 참고](https://seaborn.pydata.org/examples/index.html)

# %% [markdown]
# **- Notebook 으로 출력하기**
#
# - %matplotlib inline
#
# - 이명령어를 통해 matplot 결과물을 노트북으로 출력 가능

# %%
# Basic pie chart example
# %matplotlib inline
import matplotlib.pyplot as plt


# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i ) * flip)

# %%
sinplot()

# %% [markdown]
# **- Seaborn 을 이용한 그래프 출력**
#
# - seaborn 만 import하면 바로 사용 가능함

# %%
import seaborn as sns
sinplot()

# %% [markdown]
# **- 배경 스타일 변경**

# %%
#sns.set_style("whitegrid")
#sns.set_style("darkgrid")
sns.set_style("white")
data = np.random.normal(size=(20, 6)) + np.arange(6)/2

sns.boxplot(data=data)

# %% [markdown]
# **- 그래프 그리기**

# %%
# boxplot
# http://seaborn.pydata.org/generated/seaborn.boxplot.html
sns.set_style("dark")
data = np.random.normal(size=(20, 6)) + np.arange(6)/2
sns.boxplot(data=data)

# %%
# kdeplot
# http://seaborn.pydata.org/generated/seaborn.kdeplot.html
np.random.seed(10)
sns.set(color_codes=True)
mean, cov = [0, 2], [(1, .5), (.5, 1)]
x, y = np.random.multivariate_normal(mean, cov, size=50).T
ax = sns.kdeplot(x)
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
